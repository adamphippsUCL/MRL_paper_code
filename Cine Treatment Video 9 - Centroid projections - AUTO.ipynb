# %%
import pickle

import matplotlib.pyplot as plt

# %matplotlib notebook


import numpy as np

# %%
with open('Cine Pickles/patient_numbers.pickle', 'rb') as handle:
    pat_nums = pickle.load(handle)
    
with open('Cine Pickles/pat_num_2_frac_nums.pickle', 'rb') as handle:
    pat_num_2_frac_nums = pickle.load(handle)

# %%
patient_numbers = []

patient_fraction_dicts = []

for pat_num in pat_nums:
    
    patient_numbers.append(pat_num)
    
    fraction_numbers = []
    
    fractions_angle_dicts = []

    for frac_num in range(1, pat_num_2_frac_nums[pat_num] + 1):
        
        
        fraction_numbers.append(frac_num)
        

        print( '------>    Patient: ' + str(pat_num) + ', Fraction: ' + str(frac_num))
        
        print('')
        
        
        cine_video_name = 'pat_' + str(pat_num) + '_frac_' + str(frac_num) + '.ogv'
        
        

        
        
        
        with open('Cine Pickles/' + cine_video_name + '/number_of_minutes.pickle', 'rb') as handle:
            number_of_minutes = pickle.load(handle)

        with open('Cine Pickles/' + cine_video_name + '/cine_res.pickle', 'rb') as handle:
            cine_res = pickle.load(handle)

        with open('Cine Pickles/' + cine_video_name + '/cine_fps.pickle', 'rb') as handle:
            cine_fps = pickle.load(handle)

        with open('Cine Pickles/' + cine_video_name + '/MR_res.pickle', 'rb') as handle:
            MR_res = pickle.load(handle)


        print('MR resolution: ' + str(MR_res) )
        
        print('')


        with open('Cine Pickles/' + cine_video_name + '/MR_pixel.pickle', 'rb') as handle:
            MR_pixel = pickle.load(handle)


        with open('Cine Pickles/MR_res_2_pixel_size.pickle', 'rb') as handle:
            MR_res_2_pixel_size = pickle.load(handle)


        pixel_size = MR_res_2_pixel_size[MR_res]


        print('Pixel size: ' + str(pixel_size))
        
        print('')




        with open('Cine Pickles/MR_res_2_min_resolve.pickle', 'rb') as handle:
            MR_res_2_min_resolve = pickle.load(handle)


        min_resolvable_distance = MR_res_2_min_resolve[MR_res]


        print('Minimum resolvable distance: ' +str(min_resolvable_distance) )
        
        print('')





        ##=====================================================





        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_frames_split.pickle', 'rb') as handle:
            long_breath_hold_frames_split = pickle.load(handle)


        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_x_centroids_split_denoised.pickle', 'rb') as handle:
            long_breath_hold_x_centroids_split_denoised = pickle.load(handle)    


        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_y_centroids_split_denoised.pickle', 'rb') as handle:
            long_breath_hold_y_centroids_split_denoised = pickle.load(handle)    


        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_confidences_split.pickle', 'rb') as handle:
            long_breath_hold_confidences_split = pickle.load(handle)    









        ########################################################################






        long_breath_hold_x_centroids_denoised_unraveled = []

        #mask = [0,1,0,1,0]

        for long_breath_hold_x_centroids in long_breath_hold_x_centroids_split_denoised:

            for x_centroid in long_breath_hold_x_centroids:

                long_breath_hold_x_centroids_denoised_unraveled.append(x_centroid)



        long_breath_hold_y_centroids_denoised_unraveled = []


        for long_breath_hold_y_centroids in long_breath_hold_y_centroids_split_denoised:

            for y_centroid in long_breath_hold_y_centroids:

                long_breath_hold_y_centroids_denoised_unraveled.append(y_centroid)






        ###================================================================================================







        L = cine_res*pixel_size

        ## Vary theta in increments of pi/4, record the angle with largest spread (how that relates to body directions) -
        # Also record spread at that angle
        
        angles = []
        
        projection_data_angles = []

        
        for angle in [0 , 1/4 , 1/2 , 3/4 ]:
            
            theta = angle*np.pi
            
            angles.append(angle )
        
        #theta = (0)*np.pi/2
        
            print('angle: ' + str(angle) + ' pi' )
            
            print('______________')
            
            print('')
 
            projections =   [   long_breath_hold_y_centroids_denoised_unraveled[i]*np.cos(theta) + ( (L - long_breath_hold_x_centroids_denoised_unraveled[i]))*np.sin(theta) 
                             for i in range(0, len(long_breath_hold_y_centroids_denoised_unraveled))                     ]


            projections_sorted  = np.array( sorted(projections)   )


            median = round(np.median(projections_sorted), 1)


            projections_sorted_shifted = projections_sorted - median



            #print(median)

            bin_width = 1.5

            # bins = [ (-bin_width/2) + i*bin_width for i in range(-6,8)]


            bins = [ i*bin_width for i in range(-6, 7)]

            #print(bins)


#             plt.figure()

#             plt.grid()

            hist = plt.hist(projections_sorted_shifted , bins, density=True)









            #######################################


            within_1_5_mm = round(100*sum(1.5*hist[0][5:7]) , 1)

            print('within 1.5mm median: ' + str( within_1_5_mm ) + ' %' )
            
            print('')


            # print(hist[1][4:9])

            # print(hist[0][5:9])
            
            within_3_mm = round(100*sum(1.5*hist[0][4:8]) , 1) 

            print('within 3mm of median: ' + str( within_3_mm  ) + ' %' )
            
            print('')



            # print(hist[1][3:10])

            # print(hist[0][4:10])
            
            within_4_5_mm = round(100*sum(1.5*hist[0][3:9]) , 1) 


            print('within 4.5mm of median: ' + str( within_4_5_mm ) + ' %' )
            
            print('')

            
            
            projection_data_angles.append([ within_1_5_mm , within_3_mm , within_4_5_mm])
            
        
        
        angles_dict = dict(zip(angles , projection_data_angles))
        
        fractions_angle_dicts.append(angles_dict)
        
        
    fraction_data_dict = dict( zip( fraction_numbers , fractions_angle_dicts) )
    
    patient_fraction_dicts.append(fraction_data_dict)

patient_data_dict = dict(  zip( patient_numbers , patient_fraction_dicts))
# Out:
# ------>    Patient: 1, Fraction: 1
#
# MR resolution: 100
#
# Pixel size: 0.79
#
# Minimum resolvable distance: 1.5
#
# angle: 0 pi
# ______________
# <img src="data:image/png;base64,..." width="639.9999861283738">
# within 1.5mm median: 76.7 %
#
# within 3mm of median: 99.0 %
#
# within 4.5mm of median: 100.0 %
#
# angle: 0.25 pi
# ______________
#
# within 1.5mm median: 94.3 %
#
# within 3mm of median: 100.0 %
#
# within 4.5mm of median: 100.0 %
#
# angle: 0.5 pi
# ______________
#
# within 1.5mm median: 96.2 %
#
# within 3mm of median: 100.0 %
#
# within 4.5mm of median: 100.0 %
#
# angle: 0.75 pi
# ______________
#
# within 1.5mm median: 78.8 %
#
# within 3mm of median: 99.0 %
#
# within 4.5mm of median: 100.0 %
#
# ------>    Patient: 1, Fraction: 2
#
# MR resolution: 100
#
# Pixel size: 0.79
#
# Minimum resolvable distance: 1.5
#
# angle: 0 pi
# ______________
#
# within 1.5mm median: 56.0 %
#
# within 3mm of median: 90.1 %
#
# within 4.5mm of median: 98.1 %
#
# angle: 0.25 pi
# ...

# %%
##### Need to weight plots by time in breath hold

# %% [markdown]
# #### Save as pickle

# %%
with open('Cine Pickles/centroid_projection_data.pickle', 'wb') as handle:
    pickle.dump(patient_data_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
within_1_5_unravelled = []

within_3_unravelled = []

within_4_5_unravelled = []

angle = 0


for pat_num in [7,8,9,10]:#pat_nums:
    
    for frac_num in range(1, pat_num_2_frac_nums[pat_num] + 1):

            
            percentage_1_5 = patient_data_dict[pat_num][frac_num][angle][0]
            
            percentage_3 = patient_data_dict[pat_num][frac_num][angle][1]
            
            percentage_4_5 = patient_data_dict[pat_num][frac_num][angle][2]
            
            #print(percentage)
            
            within_1_5_unravelled.append( percentage_1_5)
            
            within_3_unravelled.append( percentage_3)
            
            within_4_5_unravelled.append( percentage_4_5)

# %%
plt.figure()

plt.grid()

bp = plt.boxplot( [ within_1_5_unravelled , within_3_unravelled , within_4_5_unravelled] ,
                 positions = [1, 2, 3],
            patch_artist = 'True' , 
            labels = [ 1.5, 3, 4.5],
           boxprops=dict(fc='lightblue', color='black'),
            medianprops=dict(color='tab:blue'),
            flierprops=dict(color='tab:red', marker = '.', markeredgecolor='tab:red')
           
        )


# bp = plt.boxplot( [ within_3_unravelled , within_4_5_unravelled ] ,
#                  positions = [1.5, 3.5],
#             patch_artist = 'True' , 
#             labels = [ 6, 3],
#            boxprops=dict(fc='orange', color='black'),
#             medianprops=dict(color='tab:blue'),
#             flierprops=dict(color='tab:red', marker = '.', markeredgecolor='tab:red')
           
#         )


#plt.legend([bp['boxes'][0:2][0], bp['boxes'][2]] , ['one', 'two'])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
bp['boxes'][0:2]

# %%
cine_video_name = 'pat_10_frac_5.ogv'

#cine_video_name = 'ZZZZZ, Modus4D  - Fraction3 - 1.ogv'

# %%
with open('Cine Pickles/' + cine_video_name + '/cine_res.pickle', 'rb') as handle:
    cine_res = pickle.load(handle)
    
with open('Cine Pickles/' + cine_video_name + '/cine_fps.pickle', 'rb') as handle:
    cine_fps = pickle.load(handle)
    
with open('Cine Pickles/' + cine_video_name + '/MR_res.pickle', 'rb') as handle:
    MR_res = pickle.load(handle)
    
print(MR_res)
    
with open('Cine Pickles/' + cine_video_name + '/MR_pixel.pickle', 'rb') as handle:
    MR_pixel = pickle.load(handle)


with open('Cine Pickles/MR_res_2_pixel_size.pickle', 'rb') as handle:
    MR_res_2_pixel_size = pickle.load(handle)
    
    

pixel_size = MR_res_2_pixel_size[MR_res]


print(pixel_size)
# Out:
# 112
# 0.56

# %%
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_frames_split.pickle', 'rb') as handle:
    long_breath_hold_frames_split = pickle.load(handle)
    
    
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_x_centroids_split_denoised.pickle', 'rb') as handle:
    long_breath_hold_x_centroids_split_denoised = pickle.load(handle)    
    
    
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_y_centroids_split_denoised.pickle', 'rb') as handle:
    long_breath_hold_y_centroids_split_denoised = pickle.load(handle)    
    
    
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/long_breath_hold_confidences_split.pickle', 'rb') as handle:
    long_breath_hold_confidences_split = pickle.load(handle)

# %%
# print(len(long_breath_hold_x_centroids_split_denoised))


# long_breath_hold_x_centroids_split_denoised = [long_breath_hold_x_centroids_split_denoised[1]] + [long_breath_hold_x_centroids_split_denoised[3]]

# long_breath_hold_y_centroids_split_denoised = [long_breath_hold_y_centroids_split_denoised[1]] + [long_breath_hold_y_centroids_split_denoised[3]]

# %%
long_breath_hold_x_centroids_denoised_unraveled = []

#mask = [0,1,0,1,0]

for long_breath_hold_x_centroids in long_breath_hold_x_centroids_split_denoised:
    
    for x_centroid in long_breath_hold_x_centroids:
    
        long_breath_hold_x_centroids_denoised_unraveled.append(x_centroid)
    

    
long_breath_hold_y_centroids_denoised_unraveled = []
    
    
for long_breath_hold_y_centroids in long_breath_hold_y_centroids_split_denoised:
    
    for y_centroid in long_breath_hold_y_centroids:
    
        long_breath_hold_y_centroids_denoised_unraveled.append(y_centroid)

# %%
# long_breath_hold_y_centroids_unraveled = [0,1]

# long_breath_hold_x_centroids_unraveled = [0,0]

# %%
plt.figure()

plt.grid()

plt.scatter(long_breath_hold_x_centroids_denoised_unraveled , long_breath_hold_y_centroids_denoised_unraveled , alpha = 0.2 )


plt.gca().invert_yaxis()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
L = cine_res*pixel_size

print(L)

confidence_intervals_90 = []

#for theta in np.arange(0 , 2*np.pi , np.pi/64):

#projections = [0]



theta = 0 

projections =   [   long_breath_hold_y_centroids_denoised_unraveled[i]*np.cos(theta) + ( (L - long_breath_hold_x_centroids_denoised_unraveled[i]))*np.sin(theta) 
                 for i in range(0, len(long_breath_hold_y_centroids_denoised_unraveled))                     ]



projections_sorted  = sorted(projections)    



mean = np.mean(projections_sorted)



plt.figure()

plt.hist(projections_sorted , 80)


# import scipy.stats as stats

# #from scipy.stats import norm




# (mu, sigma) = stats.norm.fit(projections_sorted)


# print(sigma)




percentile_95 = np.percentile(projections_sorted, 95) 

percentile_5 = np.percentile(projections_sorted, 5)

confidence_interval_90 = percentile_95 - percentile_5


confidence_intervals_90.append(confidence_interval_90)

print(confidence_interval_90)
    
    
# plt.figure()

# plt.grid()


# plt.plot(confidence_intervals_90)
# Out:
# 286.72
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 4.022201566422893

# %%
L = cine_res*pixel_size

## Vary theta in increments of pi/4, record the angle with largest spread (how that relates to body directions) -
# Also record spread at that angle

theta = (0)*np.pi/2

projections =   [   long_breath_hold_y_centroids_denoised_unraveled[i]*np.cos(theta) + ( (L - long_breath_hold_x_centroids_denoised_unraveled[i]))*np.sin(theta) 
                 for i in range(0, len(long_breath_hold_y_centroids_denoised_unraveled))                     ]


projections_sorted  = np.array( sorted(projections)   )


median = round(np.median(projections_sorted), 1)


projections_sorted_shifted = projections_sorted - median



print(median)

bin_width = 1.5

# bins = [ (-bin_width/2) + i*bin_width for i in range(-6,8)]


bins = [ i*bin_width for i in range(-6, 7)]

print(bins)


plt.figure()

plt.grid()

hist = plt.hist(projections_sorted_shifted , bins, density=True)
# Out:
# 146.5
# [-9.0, -7.5, -6.0, -4.5, -3.0, -1.5, 0.0, 1.5, 3.0, 4.5, 6.0, 7.5, 9.0]
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
print(hist[1])

print(hist[0])
# Out:
# [-9.  -7.5 -6.  -4.5 -3.  -1.5  0.   1.5  3.   4.5  6.   7.5  9. ]
# [0.         0.         0.         0.         0.0619418  0.27571305
#  0.24142898 0.08498992 0.00259291 0.         0.         0.        ]

# %%
# print(hist[1][5:8])

# print(hist[0][6:8])

print('within 1.5mm median: ' +str(   round(100*sum(1.5*hist[0][5:7]) , 1) ) + ' %' )


# print(hist[1][4:9])

# print(hist[0][5:9])

print('within 3mm of median: ' +str(   round(100*sum(1.5*hist[0][4:8]) , 1) ) + ' %' )



# print(hist[1][3:10])

# print(hist[0][4:10])

print('within 4.5mm of median: ' +str(   round(100*sum(1.5*hist[0][3:9]) , 1) ) + ' %' )
# Out:
# within 1.5mm median: 77.6 %
# within 3mm of median: 99.6 %
# within 4.5mm of median: 100.0 %

# %%
286 - 130
# Out:
# 156

# %%
fraction_data_dict
# Out:
# {2: {0: [87.1, 97.5, 100.0],
#   0.25: [98.2, 100.0, 100.0],
#   0.5: [99.8, 100.0, 100.0],
#   0.75: [90.5, 100.0, 100.0]}}
