# %%
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
# %matplotlib notebook

import pickle

import skimage

# %%
cine_video_name = 'test02_cine_frac03.ogv'

cine_video_name = 'ZZZZZ, Modus4D  - Fraction2 - 1.ogv'

# %%
frame_index =2330
cine_image = plt.imread('Cine frames/' + cine_video_name + '/frame-%04d.png' % frame_index )

from skimage.util import img_as_float


# cine_image = img_as_float(cine_image)

# cine_original = cine_image


plt.figure()

plt.imshow(cine_image)






gating_pixel = cine_image[490,3]

plt.figure()

plt.imshow([[gating_pixel]])

plt.title('Gating')


if gating_pixel[0] > 0.7:
    
    print('Gating: ON')
    
    

else:
    
    print('Gating: OFF')
    
    
    
    
beam_pixel = cine_image[504,3]


plt.figure()

plt.imshow([[beam_pixel]])

plt.title('Beam')


if beam_pixel[0] > 0.5:
    
    print('Beam: ON')

else:
    
    print('Beam: OFF')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9392/262105845.py in <module>
#       1 frame_index =2330
# ----> 2 cine_image = plt.imread('Cine frames/' + cine_video_name + '/frame-%04d.png' % frame_index )
#       3
#       4 from skimage.util import img_as_float
#       5
#
# ~\anaconda3\envs\MPhys_Environment_20211218\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2405 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2406 def imread(fname, format=None):
# -> 2407     return matplotlib.image.imread(fname, format)
#    2408
#    2409
#
# ~\anaconda3\envs\MPhys_Environment_20211218\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1499                     response = io.BytesIO(response.read())
#    1500                 return imread(response, format=ext)
# ...

# %%
with open('Cine Pickles/' + cine_video_name + '/frame_nums.pickle', 'rb') as handle:
    frame_nums = pickle.load(handle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6164/3182866901.py in <module>
# ----> 1 with open('Cine Pickles/' + cine_video_name + '/frame_nums.pickle', 'rb') as handle:
#       2     frame_nums = pickle.load(handle)
#
# NameError: name 'cine_video_name' is not defined

# %% [markdown]
# #### Auto Below

# %%
import time

# %%
with open('Cine Pickles/patient_numbers.pickle', 'rb') as handle:
    pat_nums = pickle.load(handle)
    
with open('Cine Pickles/pat_num_2_frac_nums.pickle', 'rb') as handle:
    pat_num_2_frac_nums = pickle.load(handle)

# %%
for pat_num in [10]:#pat_nums:

    for frac_num in [5]:#range(1, pat_num_2_frac_nums[pat_num] + 1):
        
        

        print( '------>' + str(pat_num) + ' , ' + str(frac_num))


        
        cine_video_name = 'pat_' + str(pat_num) + '_frac_' + str(frac_num) + '.ogv'




# for i in [3]:
    
    

#     cine_video_name = 'ZZZZZ, Modus4D  - Fraction' + str(i) + ' - 1.ogv'





        with open('Cine Pickles/' + cine_video_name + '/frame_nums.pickle', 'rb') as handle:
            frame_nums = pickle.load(handle)


















        beam_states = []

        gating_states = []


        for frame_index in frame_nums:

            cine_image = plt.imread('Cine frames/' + cine_video_name + '/frame-%04d.png' % frame_index )

            gating_pixel = cine_image[490,3]

            #plt.figure()

            #plt.imshow([[gating_pixel]])

            #plt.title('Gating')


            if gating_pixel[0] > 0.6:

                #print('Gating: ON')

                gating_states.append(1)



            else:

                #print('Gating: OFF')

                gating_states.append(0)




            beam_pixel = cine_image[504,3]


            #plt.figure()

            #plt.imshow([[beam_pixel]])

            #plt.title('Beam')


            if beam_pixel[0] > 0.6:

                #print('Beam: ON')

                beam_states.append(1)

            else:

                #print('Beam: OFF')

                beam_states.append(0)





        with open('Cine Pickles/' + cine_video_name + '/All_Frames_Beam_States.pickle', 'wb') as handle:
            pickle.dump(beam_states, handle, protocol=pickle.HIGHEST_PROTOCOL)


        with open('Cine Pickles/' + cine_video_name + '/All_Frames_Gating_States.pickle', 'wb') as handle:
            pickle.dump(gating_states, handle, protocol=pickle.HIGHEST_PROTOCOL)






        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_frames_split.pickle', 'rb') as handle:
            breath_hold_frames_split = pickle.load(handle)



        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_frames_split.pickle', 'rb') as handle:
            breath_hold_frames_split = pickle.load(handle)




        breath_hold_masks = []


        breath_hold_numbers = []


        for breath_hold_number in range(0, len(breath_hold_frames_split)):


            breath_hold_numbers.append(breath_hold_number)



            this_breath_hold_mask = [ frame in breath_hold_frames_split[breath_hold_number] for frame in frame_nums]

            breath_hold_masks.append(this_breath_hold_mask)






        breath_hold_gating_states_split = []


        breath_hold_beam_states_split = []




        for breath_hold_number in range(0, len(breath_hold_frames_split)):

            this_breath_hold_gating_states = np.array(gating_states)[breath_hold_masks[breath_hold_number]]

            this_breath_hold_beam_states = np.array(beam_states)[breath_hold_masks[breath_hold_number]]

            breath_hold_gating_states_split.append(this_breath_hold_gating_states)

            breath_hold_beam_states_split.append(this_breath_hold_beam_states)






        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_gating_states_split.pickle', 'wb') as handle:
            pickle.dump(breath_hold_gating_states_split, handle, protocol=pickle.HIGHEST_PROTOCOL)


        with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_beam_states_split.pickle', 'wb') as handle:
            pickle.dump(breath_hold_beam_states_split, handle, protocol=pickle.HIGHEST_PROTOCOL)
            
        print('done!')    
        #time.sleep(30)
# Out:
# ------>10 , 5
# done!

# %%
f = 2330

print(gating_states[f])

print( beam_states[f])
# Out:
# 1
# 0

# %%
plt.figure()

plt.plot(frame_nums, beam_states)
# Out:
# <img src="data:image/png;base64,..." width="703.6363483854565">

# %%
with open('Cine Pickles/' + cine_video_name + '/All_Frames_Beam_States.pickle', 'wb') as handle:
    pickle.dump(beam_states, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
    
with open('Cine Pickles/' + cine_video_name + '/All_Frames_Gating_States.pickle', 'wb') as handle:
    pickle.dump(gating_states, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_frames_split.pickle', 'rb') as handle:
    breath_hold_frames_split = pickle.load(handle)

# %%
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_frames_split.pickle', 'rb') as handle:
    breath_hold_frames_split = pickle.load(handle)
    
    


breath_hold_masks = []


breath_hold_numbers = []


for breath_hold_number in range(0, len(breath_hold_frames_split)):
    
    
    breath_hold_numbers.append(breath_hold_number)
    
    
    
    this_breath_hold_mask = [ frame in breath_hold_frames_split[breath_hold_number] for frame in frame_nums]
    
    breath_hold_masks.append(this_breath_hold_mask)
    
    
    



breath_hold_gating_states_split = []


breath_hold_beam_states_split = []




for breath_hold_number in range(0, len(breath_hold_frames_split)):
    
    this_breath_hold_gating_states = np.array(gating_states)[breath_hold_masks[breath_hold_number]]
    
    this_breath_hold_beam_states = np.array(beam_states)[breath_hold_masks[breath_hold_number]]
    
    breath_hold_gating_states_split.append(this_breath_hold_gating_states)
    
    breath_hold_beam_states_split.append(this_breath_hold_beam_states)

# %%
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_gating_states_split.pickle', 'wb') as handle:
    pickle.dump(breath_hold_gating_states_split, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
    
with open('Cine Pickles/' + cine_video_name + '/Analysising Breath-holds/breath_hold_beam_states_split.pickle', 'wb') as handle:
    pickle.dump(breath_hold_beam_states_split, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
print(len(breath_hold_gating_states_split))
# Out:
# 18
